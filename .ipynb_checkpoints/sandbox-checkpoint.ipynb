# %%
import pandas

# %%
from importlib import reload

# %%
import analyst

# %%
def stockpup_filename():
    return 'A_quarterly_financial_data.csv'

# %%
reload(analyst)
# Out:
# <module 'analyst' from '/Users/jakeitegboje/gym/haystack/analyst.py'>

# %%
stockpup = analyst.Analyst(source='STOCKPUP', ticker='B').get_stock()

# %%
edgar = analyst.Analyst(source='EDGAR', ticker='A').get_stock()

# %%
edgar_raw = edgar.get_raw_data()
# Out:
# 2021-06-06 02:33:37.353123::Ticker::A::Getting RAW data from A.csv::

# %%
stockpup_raw = stockpup.get_raw_data()
# Out:
# 2021-06-06 02:33:37.762705::Ticker::B::Getting RAW data from BAC_quarterly_financial_data.csv::

# %%
stockpup_annual = stockpup.get_annual_data(stockpup_raw)

# %%
stockpup_annual
# Out:
#                    Shares  Shares split adjusted  Split factor         Assets  \
# YEAR QUARTER
# 2017 4        10243688896            10243688896             1  2281234000000
#      3        10430613675            10430613675             1  2283896000000
#      2         9850580344             9850580344             1  2254529000000
#      1         9951898904             9951898904             1  2247701000000
# 2016 4        10025121972            10025121972             1  2187702000000
# ...                   ...                    ...           ...            ...
# 1995 1          271404569             1085618276             4   183854000000
# 1994 4          276477155             1105908620             4   169604000000
#      3          275621566             1102486264             4   170912000000
#      2          276591985             1106367940             4   164398000000
#      1          274715504             1098862016             4   165071000000
#
# ...
